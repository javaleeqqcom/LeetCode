# %%
from pathlib import Path

from agents.analyze_agent import AnalyzeAgent
from agents.case_generator_agent import CaseGeneratorAgent

QUESTION = Path(
    r"Question/3660. Jump Game IX/题目.txt"
).read_text(encoding="utf-8")


STUDENT_CODE = Path(
    r"Question/3660. Jump Game IX/V5.0.py"
).read_text(encoding="utf-8")

LANGUAGE = "python"

# %%
print("=" * 80)
print("STEP 1 : Analyze")
print("=" * 80)

analyze_agent = AnalyzeAgent()

analysis = analyze_agent.run(
    question=QUESTION,
    student_code=STUDENT_CODE,
    language=LANGUAGE,
)

print(analysis.model_dump_json(indent=2))
# Out:
# ================================================================================
# STEP 1 : Analyze
# ================================================================================
# d:\Users\java_lee\Documents\GitHub\LeetCode\agents\analyze_agent.py:16: LangChainDeprecationWarning: The class `ChatOllama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the `langchain-ollama package and should be used instead. To use it run `pip install -U `langchain-ollama` and import as `from `langchain_ollama import ChatOllama``.
#   self.llm = llm or ChatOllama(
# {
#   "language": "python",
#   "main_function": "maxValue",
#   "function_type": "array",
#   "input_style": "Args",
#   "need_conversion": false,
#   "custom_types": [
#     "Priority_Union_Set"
#   ],
#   "complexity": {
#     "time_complexity": "O(n log n)",
#     "space_complexity": "O(n)",
#     "bottleneck": "The use of a stack and union-find operations with path compression and union by priority, which results in an amortized logarithmic time per operation."
#   },
#   "scale_config": {
#     "num": 100000,
#     "mean_scale": 1000000000.0,
#     "second_moment": 1e+18,
#     "distribution": "lognormal"
#   },
#   "test_strategy": [
#     "Test with increasing sequence of numbers to verify monotonic behavior.",
#     "Test with decreasing sequence of numbers to verify reverse monotonic behavior.",
#     "Test with random permutations to ensure correctness under various orderings.",
#     "Test with duplicate values to check handling of equal elements in the priority union set.",
#     "Test with a single element array to verify base case handling.",
#     "Test with maximum allowed input size (10^5 elements) to check performance limits."
#   ],
#   "edge_cases": [
#     "Array with one element.",
#     "Array with all elements equal.",
#     "Array sorted in ascending order.",
#     "Array sorted in descending order.",
#     "Array with negative numbers (if allowed by constraints)."
#   ],
#   "stress_patterns": [
#     "Large arrays with elements near the upper bound of constraints (10^9).",
#     "Arrays with many duplicates to stress the union-find logic.",
#     "Arrays with elements in a pattern that maximizes stack operations in the monotonic stack."
#   ],
#   "rag_queries": [
#     "Jump game with constraints on index movement based on value comparison",
#     "Monotonic stack with union-find data structure for maximum value tracking",
#     "Priority-based union-find implementation for dynamic connectivity problems",
#     "Efficient algorithms for maximum reachable value in jump games with specific rules"
#   ],
#   "corrected_code": null,
#   "correction_reason": null
# }

# %%
print("\n")
print("=" * 80)
print("STEP 2 : Generate Case Generator")
print("=" * 80)

case_agent = CaseGeneratorAgent()

case_code = case_agent.run(
    question=QUESTION,
    student_code=STUDENT_CODE,
    language=LANGUAGE,
    analysis=analysis,
)

print(case_code)


out_path = Path(
    r"Question/3660. Jump Game IX/case_generator_ai.py"
)

out_path.write_text(case_code.content, encoding="utf-8")

print("\nSaved:", out_path)
# Out:
# ================================================================================
# STEP 2 : Generate Case Generator
# ================================================================================
# content='```python\ndef case_generator(scale):\n    import numpy as np\n    import random as rd\n    \n    MIN_N = 1\n    MAX_N = 10**5\n    UNIQUE_RATE = 0.9\n    SMALL_RATE = 0.8\n    MAX_VAL = 10**9\n    \n    n = np.clip(int(round(scale)), MIN_N, MAX_N)\n    \n    # A. 独特元素的个数\n    distinct = n if rd.random() < UNIQUE_RATE else rd.randint(1, n)\n\n    # B. 选择数组数值分布\n    if rd.random() < SMALL_RATE:\n        nums = np.arange(1, distinct + 1)\n    else:\n        nums = np.random.randint(1, MAX_VAL + 1, size=distinct)\n\n    # 生成随机数组\n    if distinct == n:\n        np.random.shuffle(nums)\n    else:\n        nums = np.random.choice(nums, size=n, replace=True)\n\n    # C. 选择一部分进行排序\n    sorted_rate = np.random.random()\n    sorted_mask = np.random.random(size=n) <= sorted_rate\n    nums[sorted_mask] = np.sort(nums[sorted_mask])[::-1]\n    \n    return {\n        "input": (\n            nums.tolist(),\n        ),\n    }\n```' additional_kwargs={} response_metadata={'model': 'qwen3-coder-30b-q8:latest', 'created_at': '2026-05-15T15:22:23.7916102Z', 'message': {'role': 'assistant', 'content': ''}, 'done': True, 'done_reason': 'stop', 'total_duration': 52098287200, 'load_duration': 13085127000, 'prompt_eval_count': 3563, 'prompt_eval_duration': 14417619100, 'eval_count': 271, 'eval_duration': 24502901800} id='lc_run--019e2c3a-7f2b-77b2-84c7-9cf105483c54-0' tool_calls=[] invalid_tool_calls=[]
#
# Saved: Question\3660. Jump Game IX\case_generator_ai.py
